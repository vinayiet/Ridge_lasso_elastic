# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('mpg')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.drop("name", axis= 1, inplace = True)

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df['horsepower'].fillna(df['horsepower'].median())
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df['origin'].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
df['origin'] = df['origin'].map({'usa':1, 'japan':2, 'europe':3})

# %%
df['origin'] = df['origin'].astype(int)

# %%
# seperate x and y 
x = df.drop('mpg', axis = 1)
y = df['mpg']

# %%
x.isna().sum()
# Out:
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
y.isna().sum()
# Out:
# 0

# %%
# train test split 
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test =  train_test_split(x,y, test_size = 0.3, random_state = 1)

# %%
x_train['weight'] = x_train['weight'].fillna(x_train['weight'].mean())

# %%
x_train = x_train.dropna(axis=1)

# %%
x_train.shape, x_test.shape
# Out:
# ((278, 6), (120, 7))

# %%
x_test = x_test.drop(columns=['horsepower'], errors='ignore')

# %%
from sklearn.linear_model import LinearRegression

regression_model = LinearRegression()

# %%
regression_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
for i, col_name in enumerate(x_train.columns):
    print(f"The coefficient for {col_name} is {regression_model.coef_[i]}")
# Out:
# The coefficient for cylinders is -0.3326424699755278
# The coefficient for displacement is 0.025011359146140173
# The coefficient for weight is -0.007928109200077065
# The coefficient for acceleration is 0.13214733880720653
# The coefficient for model_year is 0.8579828282650561
# The coefficient for origin is 1.466301210578919

# %%
from sklearn.metrics import r2_score

y_pred_linear = regression_model.predict(x_test)
r2_linear = r2_score(y_test, y_pred_linear)
print(r2_linear)
# Out:
# 0.8372022826815706

# %%
# Ridge regression

# %%
from sklearn.linear_model import Ridge

# Correct instantiation of the Ridge regression model
ridge_regression_model = Ridge(alpha=0.1)
ridge_regression_model.fit(x_train, y_train)

for i , col_name in enumerate(x_train.columns):
    print(f"the coff for {col_name} is {ridge_regression_model.coef_[i]}")
# Out:
# the coff for cylinders is -0.3320075210531885
# the coff for displacement is 0.024987573001459654
# the coff for weight is -0.007927508224666186
# the coff for acceleration is 0.13207215598946606
# the coff for model_year is 0.8578915980472391
# the coff for origin is 1.4647283104342497

# %%
# We don't see much variation s in  rdge regression

# %%
# Lasso Regression model 
from sklearn.linear_model import Lasso

# %%
lasso_model = Lasso(alpha = 0.5)
lasso_model.fit(x_train, y_train)

for i , col_name in enumerate(x_train.columns):
    print(f"the coff for {col_name} is {lasso_model.coef_[i]}")
# Out:
# the coff for cylinders is -0.0
# the coff for displacement is 0.0040228723418518735
# the coff for weight is -0.007149808864194651
# the coff for acceleration is 0.0
# the coff for model_year is 0.7545895023415667
# the coff for origin is 0.0

# %%
# Three feature are 0, Lasso helps in feature selection

# %%
y_pred_lasso = lasso_model.predict(x_test)
r2_lasso = r2_score(y_test, y_pred_lasso)
print(r2_lasso)
# Out:
# 0.8294009880632177

# %%
from sklearn.linear_model import ElasticNet
ElasticNet(alpha = 1, l1_ratio=0.5)
# Out:
# ElasticNet(alpha=1)

# %%
ElasticNet_model = ElasticNet(alpha = 1, l1_ratio=0.5)
ElasticNet_model.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=1)

# %%
y_pred_elastic_net = ElasticNet_model.predict(x_test)
r2_ElasticNet = r2_score(y_test, y_pred_elastic_net)
print(r2_ElasticNet)
# Out:
# 0.8303664992359676
